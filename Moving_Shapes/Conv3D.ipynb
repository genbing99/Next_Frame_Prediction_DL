# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.6/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.6/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     490         """
# --> 491         parts = [self.recv(flags, copy=copy, track=track)]
#     492         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.6/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-9a9a89271754> in <module>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/gdrive/')
#
# /usr/local/lib/python3.6/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, use_metadata_server)
#     249       with _output.use_tags('dfs-auth-dance'):
#     250         with open(fifo, 'w') as fifo_file:
# --> 251           fifo_file.write(get_code(auth_prompt) + '\n')
#     252       wrote_to_fifo = True
#     253     elif case == 5:
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     702             self._parent_ident,
#     703             self._parent_header,
# --> 704             password=False,
#     705         )
#     706
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     732             except KeyboardInterrupt:
#     733                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 734                 raise KeyboardInterrupt
#     735             else:
#     736                 break
#
# KeyboardInterrupt:

# %%
cd '/content/gdrive/My Drive/VIP_Project'

# %%
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import pylab as plt

# %%
num_epoch = 100
batch_size = 1000

in_timesteps  = range(0,19)
out_timesteps = range(1,20)

# prepare data
data = np.load( "moving-shapes-2-tr-images.npy" )

# training set
x_tr = data[:5000,in_timesteps]
y_tr = data[:5000,out_timesteps]
tr_set = data[0:5000, :, :, :]

# validation set
x_te = data[5000:6000,in_timesteps]
y_te = data[5000:6000,out_timesteps]
te_set = data[5000:6000, :, :, :]

#print (np.shape(x_tr), np.shape(y_tr), np.shape(x_te), np.shape(y_te))
print (np.shape(x_te), np.shape(y_te))
# Out:
# (1000, 19, 64, 64, 3) (1000, 19, 64, 64, 3)

# %%
#Build a model
seq = keras.Sequential(
    [
        keras.Input(
            shape=(None, 64, 64, 3)    # (64,64,1) for MNISt , (64,64,3) for moving shape
        ),  # Variable-length sequence of 40x40x1 frames
        layers.Conv3D(
            filters=64, kernel_size=(3, 3, 3), padding="same"
        ),
        layers.BatchNormalization(),
        layers.Conv3D(
            filters=64, kernel_size=(3, 3, 3), padding="same"
        ),
        layers.BatchNormalization(),
        layers.Conv3D(
            filters=64, kernel_size=(3, 3, 3), padding="same"
        ),
        layers.BatchNormalization(),
        layers.Conv3D(
            filters=64, kernel_size=(3, 3, 3), padding="same"
        ),
        layers.BatchNormalization(),
        layers.Conv3D(
            filters=64, kernel_size=(3, 3, 3), activation="sigmoid", padding="same"
        ),
    ]
)
seq.compile(loss="binary_crossentropy", optimizer="adadelta")

# %%
seq.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d (Conv3D)              (None, None, 64, 64, 3)   246
# _________________________________________________________________
# batch_normalization (BatchNo (None, None, 64, 64, 3)   12
# _________________________________________________________________
# conv3d_1 (Conv3D)            (None, None, 64, 64, 3)   246
# _________________________________________________________________
# batch_normalization_1 (Batch (None, None, 64, 64, 3)   12
# _________________________________________________________________
# conv3d_2 (Conv3D)            (None, None, 64, 64, 3)   246
# _________________________________________________________________
# batch_normalization_2 (Batch (None, None, 64, 64, 3)   12
# _________________________________________________________________
# conv3d_3 (Conv3D)            (None, None, 64, 64, 3)   246
# _________________________________________________________________
# batch_normalization_3 (Batch (None, None, 64, 64, 3)   12
# _________________________________________________________________
# conv3d_4 (Conv3D)            (None, None, 64, 64, 3)   246
# =================================================================
# Total params: 1,278
# Trainable params: 1,254
# Non-trainable params: 24
# _________________________________________________________________

# %%
def generator(X, y, batch_size):
    while True:
        for start in range(0, len(X), batch_size):
            end = min(start + batch_size, len(X))
            yield np.array(X[start:end]/255), np.array(y[start:end]/255)

# %%
batch_size=8

checkpoint_filepath = '/content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator'
model_checkpoint_callback = keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_loss',
    save_best_only=True,
    verbose=1
  )

# %%
history = seq.fit_generator(
    generator(x_tr, y_tr, batch_size),
    steps_per_epoch = len(x_tr)/batch_size,
    epochs=500,
    verbose=1,
    validation_data=generator(x_te, y_te, batch_size),
    validation_steps = len(x_te)/batch_size,
    callbacks=[model_checkpoint_callback]
)
# Out:
# WARNING:tensorflow:From <ipython-input-10-0ad9da4a72a2>:8: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/500
#   2/625 [..............................] - ETA: 48s - loss: 0.7768WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0302s vs `on_train_batch_end` time: 0.0682s). Check your callbacks.
# 625/625 [==============================] - ETA: 0s - loss: 0.7661
# Epoch 00001: val_loss improved from inf to 0.75204, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.7661 - val_loss: 0.7520
# Epoch 2/500
# 625/625 [==============================] - ETA: 0s - loss: 0.7450
# Epoch 00002: val_loss improved from 0.75204 to 0.73397, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.7450 - val_loss: 0.7340
# Epoch 3/500
# 625/625 [==============================] - ETA: 0s - loss: 0.7203
# Epoch 00003: val_loss improved from 0.73397 to 0.70826, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.7203 - val_loss: 0.7083
# Epoch 4/500
# 625/625 [==============================] - ETA: 0s - loss: 0.6939
# Epoch 00004: val_loss improved from 0.70826 to 0.68177, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.6939 - val_loss: 0.6818
# Epoch 5/500
# 625/625 [==============================] - ETA: 0s - loss: 0.6693
# Epoch 00005: val_loss improved from 0.68177 to 0.65849, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.6693 - val_loss: 0.6585
# Epoch 6/500
# 625/625 [==============================] - ETA: 0s - loss: 0.6494
# Epoch 00006: val_loss improved from 0.65849 to 0.64028, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.6494 - val_loss: 0.6403
# Epoch 7/500
# 625/625 [==============================] - ETA: 0s - loss: 0.6342
# Epoch 00007: val_loss improved from 0.64028 to 0.62650, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.6342 - val_loss: 0.6265
# Epoch 8/500
# 625/625 [==============================] - ETA: 0s - loss: 0.6225
# Epoch 00008: val_loss improved from 0.62650 to 0.61579, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 71ms/step - loss: 0.6225 - val_loss: 0.6158
# Epoch 9/500
# 625/625 [==============================] - ETA: 0s - loss: 0.6133
# Epoch 00009: val_loss improved from 0.61579 to 0.60704, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.6133 - val_loss: 0.6070
# Epoch 10/500
# 625/625 [==============================] - ETA: 0s - loss: 0.6055
# Epoch 00010: val_loss improved from 0.60704 to 0.59953, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.6055 - val_loss: 0.5995
# Epoch 11/500
# 625/625 [==============================] - ETA: 0s - loss: 0.5988
# Epoch 00011: val_loss improved from 0.59953 to 0.59280, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 71ms/step - loss: 0.5988 - val_loss: 0.5928
# Epoch 12/500
# 625/625 [==============================] - ETA: 0s - loss: 0.5926
# Epoch 00012: val_loss improved from 0.59280 to 0.58656, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.5926 - val_loss: 0.5866
# Epoch 13/500
# 625/625 [==============================] - ETA: 0s - loss: 0.5868
# Epoch 00013: val_loss improved from 0.58656 to 0.58062, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 71ms/step - loss: 0.5868 - val_loss: 0.5806
# Epoch 14/500
# 625/625 [==============================] - ETA: 0s - loss: 0.5813
# Epoch 00014: val_loss improved from 0.58062 to 0.57486, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.5813 - val_loss: 0.5749
# Epoch 15/500
# 625/625 [==============================] - ETA: 0s - loss: 0.5758
# Epoch 00015: val_loss improved from 0.57486 to 0.56920, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 71ms/step - loss: 0.5758 - val_loss: 0.5692
# Epoch 16/500
# 625/625 [==============================] - ETA: 0s - loss: 0.5705
# Epoch 00016: val_loss improved from 0.56920 to 0.56358, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.5705 - val_loss: 0.5636
# Epoch 17/500
# 625/625 [==============================] - ETA: 0s - loss: 0.5650
# Epoch 00017: val_loss improved from 0.56358 to 0.55795, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 71ms/step - loss: 0.5650 - val_loss: 0.5579
# Epoch 18/500
# 625/625 [==============================] - ETA: 0s - loss: 0.5596
# Epoch 00018: val_loss improved from 0.55795 to 0.55227, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.5596 - val_loss: 0.5523
# Epoch 19/500
# 625/625 [==============================] - ETA: 0s - loss: 0.5540
# Epoch 00019: val_loss improved from 0.55227 to 0.54651, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.5540 - val_loss: 0.5465
# Epoch 20/500
# 625/625 [==============================] - ETA: 0s - loss: 0.5484
# Epoch 00020: val_loss improved from 0.54651 to 0.54065, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.5484 - val_loss: 0.5406
# Epoch 21/500
# 625/625 [==============================] - ETA: 0s - loss: 0.5426
# Epoch 00021: val_loss improved from 0.54065 to 0.53466, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.5426 - val_loss: 0.5347
# Epoch 22/500
# 625/625 [==============================] - ETA: 0s - loss: 0.5366
# Epoch 00022: val_loss improved from 0.53466 to 0.52853, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 71ms/step - loss: 0.5366 - val_loss: 0.5285
# Epoch 23/500
# 625/625 [==============================] - ETA: 0s - loss: 0.5305
# Epoch 00023: val_loss improved from 0.52853 to 0.52225, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.5305 - val_loss: 0.5222
# Epoch 24/500
# 625/625 [==============================] - ETA: 0s - loss: 0.5242
# Epoch 00024: val_loss improved from 0.52225 to 0.51578, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 71ms/step - loss: 0.5242 - val_loss: 0.5158
# Epoch 25/500
# 625/625 [==============================] - ETA: 0s - loss: 0.5177
# Epoch 00025: val_loss improved from 0.51578 to 0.50913, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 71ms/step - loss: 0.5177 - val_loss: 0.5091
# Epoch 26/500
# 625/625 [==============================] - ETA: 0s - loss: 0.5110
# Epoch 00026: val_loss improved from 0.50913 to 0.50229, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.5110 - val_loss: 0.5023
# Epoch 27/500
# 625/625 [==============================] - ETA: 0s - loss: 0.5041
# Epoch 00027: val_loss improved from 0.50229 to 0.49527, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.5041 - val_loss: 0.4953
# Epoch 28/500
# 625/625 [==============================] - ETA: 0s - loss: 0.4970
# Epoch 00028: val_loss improved from 0.49527 to 0.48807, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.4970 - val_loss: 0.4881
# Epoch 29/500
# 625/625 [==============================] - ETA: 0s - loss: 0.4897
# Epoch 00029: val_loss improved from 0.48807 to 0.48071, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 71ms/step - loss: 0.4897 - val_loss: 0.4807
# Epoch 30/500
# 625/625 [==============================] - ETA: 0s - loss: 0.4823
# Epoch 00030: val_loss improved from 0.48071 to 0.47319, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 71ms/step - loss: 0.4823 - val_loss: 0.4732
# Epoch 31/500
# 625/625 [==============================] - ETA: 0s - loss: 0.4747
# Epoch 00031: val_loss improved from 0.47319 to 0.46553, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.4747 - val_loss: 0.4655
# Epoch 32/500
# 625/625 [==============================] - ETA: 0s - loss: 0.4669
# Epoch 00032: val_loss improved from 0.46553 to 0.45771, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.4669 - val_loss: 0.4577
# Epoch 33/500
# 625/625 [==============================] - ETA: 0s - loss: 0.4590
# Epoch 00033: val_loss improved from 0.45771 to 0.44971, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 71ms/step - loss: 0.4590 - val_loss: 0.4497
# Epoch 34/500
# 625/625 [==============================] - ETA: 0s - loss: 0.4509
# Epoch 00034: val_loss improved from 0.44971 to 0.44150, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 71ms/step - loss: 0.4509 - val_loss: 0.4415
# Epoch 35/500
# 625/625 [==============================] - ETA: 0s - loss: 0.4426
# Epoch 00035: val_loss improved from 0.44150 to 0.43305, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 71ms/step - loss: 0.4426 - val_loss: 0.4330
# Epoch 36/500
# 625/625 [==============================] - ETA: 0s - loss: 0.4340
# Epoch 00036: val_loss improved from 0.43305 to 0.42431, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.4340 - val_loss: 0.4243
# Epoch 37/500
# 625/625 [==============================] - ETA: 0s - loss: 0.4251
# Epoch 00037: val_loss improved from 0.42431 to 0.41527, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.4251 - val_loss: 0.4153
# Epoch 38/500
# 625/625 [==============================] - ETA: 0s - loss: 0.4159
# Epoch 00038: val_loss improved from 0.41527 to 0.40590, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.4159 - val_loss: 0.4059
# Epoch 39/500
# 625/625 [==============================] - ETA: 0s - loss: 0.4064
# Epoch 00039: val_loss improved from 0.40590 to 0.39620, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.4064 - val_loss: 0.3962
# Epoch 40/500
# 625/625 [==============================] - ETA: 0s - loss: 0.3965
# Epoch 00040: val_loss improved from 0.39620 to 0.38618, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.3965 - val_loss: 0.3862
# Epoch 41/500
# 625/625 [==============================] - ETA: 0s - loss: 0.3863
# Epoch 00041: val_loss improved from 0.38618 to 0.37588, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.3863 - val_loss: 0.3759
# Epoch 42/500
# 625/625 [==============================] - ETA: 0s - loss: 0.3758
# Epoch 00042: val_loss improved from 0.37588 to 0.36535, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.3758 - val_loss: 0.3654
# Epoch 43/500
# 625/625 [==============================] - ETA: 0s - loss: 0.3651
# Epoch 00043: val_loss improved from 0.36535 to 0.35468, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.3651 - val_loss: 0.3547
# Epoch 44/500
# 625/625 [==============================] - ETA: 0s - loss: 0.3543
# Epoch 00044: val_loss improved from 0.35468 to 0.34394, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.3543 - val_loss: 0.3439
# Epoch 45/500
# 625/625 [==============================] - ETA: 0s - loss: 0.3435
# Epoch 00045: val_loss improved from 0.34394 to 0.33327, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.3435 - val_loss: 0.3333
# Epoch 46/500
# 625/625 [==============================] - ETA: 0s - loss: 0.3328
# Epoch 00046: val_loss improved from 0.33327 to 0.32276, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.3328 - val_loss: 0.3228
# Epoch 47/500
# 625/625 [==============================] - ETA: 0s - loss: 0.3224
# Epoch 00047: val_loss improved from 0.32276 to 0.31252, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.3224 - val_loss: 0.3125
# Epoch 48/500
# 625/625 [==============================] - ETA: 0s - loss: 0.3123
# Epoch 00048: val_loss improved from 0.31252 to 0.30266, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.3123 - val_loss: 0.3027
# Epoch 49/500
# 625/625 [==============================] - ETA: 0s - loss: 0.3026
# Epoch 00049: val_loss improved from 0.30266 to 0.29327, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.3026 - val_loss: 0.2933
# Epoch 50/500
# 625/625 [==============================] - ETA: 0s - loss: 0.2935
# Epoch 00050: val_loss improved from 0.29327 to 0.28440, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.2935 - val_loss: 0.2844
# Epoch 51/500
# 625/625 [==============================] - ETA: 0s - loss: 0.2849
# Epoch 00051: val_loss improved from 0.28440 to 0.27609, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.2849 - val_loss: 0.2761
# Epoch 52/500
# 625/625 [==============================] - ETA: 0s - loss: 0.2768
# Epoch 00052: val_loss improved from 0.27609 to 0.26838, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.2768 - val_loss: 0.2684
# Epoch 53/500
# 625/625 [==============================] - ETA: 0s - loss: 0.2694
# Epoch 00053: val_loss improved from 0.26838 to 0.26127, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.2694 - val_loss: 0.2613
# Epoch 54/500
# 625/625 [==============================] - ETA: 0s - loss: 0.2626
# Epoch 00054: val_loss improved from 0.26127 to 0.25475, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.2626 - val_loss: 0.2547
# Epoch 55/500
# 625/625 [==============================] - ETA: 0s - loss: 0.2564
# Epoch 00055: val_loss improved from 0.25475 to 0.24878, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.2564 - val_loss: 0.2488
# Epoch 56/500
# 625/625 [==============================] - ETA: 0s - loss: 0.2507
# Epoch 00056: val_loss improved from 0.24878 to 0.24335, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.2507 - val_loss: 0.2434
# Epoch 57/500
# 625/625 [==============================] - ETA: 0s - loss: 0.2456
# Epoch 00057: val_loss improved from 0.24335 to 0.23842, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.2456 - val_loss: 0.2384
# Epoch 58/500
# 625/625 [==============================] - ETA: 0s - loss: 0.2409
# Epoch 00058: val_loss improved from 0.23842 to 0.23395, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.2409 - val_loss: 0.2340
# Epoch 59/500
# 625/625 [==============================] - ETA: 0s - loss: 0.2366
# Epoch 00059: val_loss improved from 0.23395 to 0.22991, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.2366 - val_loss: 0.2299
# Epoch 60/500
# 625/625 [==============================] - ETA: 0s - loss: 0.2328
# Epoch 00060: val_loss improved from 0.22991 to 0.22624, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.2328 - val_loss: 0.2262
# Epoch 61/500
# 625/625 [==============================] - ETA: 0s - loss: 0.2293
# Epoch 00061: val_loss improved from 0.22624 to 0.22293, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.2293 - val_loss: 0.2229
# Epoch 62/500
# 625/625 [==============================] - ETA: 0s - loss: 0.2262
# Epoch 00062: val_loss improved from 0.22293 to 0.21992, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.2262 - val_loss: 0.2199
# Epoch 63/500
# 625/625 [==============================] - ETA: 0s - loss: 0.2233
# Epoch 00063: val_loss improved from 0.21992 to 0.21719, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.2233 - val_loss: 0.2172
# Epoch 64/500
# 625/625 [==============================] - ETA: 0s - loss: 0.2208
# Epoch 00064: val_loss improved from 0.21719 to 0.21472, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.2208 - val_loss: 0.2147
# Epoch 65/500
# 625/625 [==============================] - ETA: 0s - loss: 0.2184
# Epoch 00065: val_loss improved from 0.21472 to 0.21246, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.2184 - val_loss: 0.2125
# Epoch 66/500
# 625/625 [==============================] - ETA: 0s - loss: 0.2163
# Epoch 00066: val_loss improved from 0.21246 to 0.21040, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.2163 - val_loss: 0.2104
# Epoch 67/500
# 625/625 [==============================] - ETA: 0s - loss: 0.2143
# Epoch 00067: val_loss improved from 0.21040 to 0.20851, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.2143 - val_loss: 0.2085
# Epoch 68/500
# 625/625 [==============================] - ETA: 0s - loss: 0.2125
# Epoch 00068: val_loss improved from 0.20851 to 0.20677, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.2125 - val_loss: 0.2068
# Epoch 69/500
# 625/625 [==============================] - ETA: 0s - loss: 0.2109
# Epoch 00069: val_loss improved from 0.20677 to 0.20517, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.2109 - val_loss: 0.2052
# Epoch 70/500
# 625/625 [==============================] - ETA: 0s - loss: 0.2093
# Epoch 00070: val_loss improved from 0.20517 to 0.20369, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.2093 - val_loss: 0.2037
# Epoch 71/500
# 625/625 [==============================] - ETA: 0s - loss: 0.2079
# Epoch 00071: val_loss improved from 0.20369 to 0.20232, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.2079 - val_loss: 0.2023
# Epoch 72/500
# 625/625 [==============================] - ETA: 0s - loss: 0.2066
# Epoch 00072: val_loss improved from 0.20232 to 0.20105, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.2066 - val_loss: 0.2010
# Epoch 73/500
# 625/625 [==============================] - ETA: 0s - loss: 0.2054
# Epoch 00073: val_loss improved from 0.20105 to 0.19986, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.2054 - val_loss: 0.1999
# Epoch 74/500
# 625/625 [==============================] - ETA: 0s - loss: 0.2042
# Epoch 00074: val_loss improved from 0.19986 to 0.19874, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.2042 - val_loss: 0.1987
# Epoch 75/500
# 625/625 [==============================] - ETA: 0s - loss: 0.2031
# Epoch 00075: val_loss improved from 0.19874 to 0.19770, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.2031 - val_loss: 0.1977
# Epoch 76/500
# 625/625 [==============================] - ETA: 0s - loss: 0.2021
# Epoch 00076: val_loss improved from 0.19770 to 0.19672, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.2021 - val_loss: 0.1967
# Epoch 77/500
# 625/625 [==============================] - ETA: 0s - loss: 0.2012
# Epoch 00077: val_loss improved from 0.19672 to 0.19580, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.2012 - val_loss: 0.1958
# Epoch 78/500
# 625/625 [==============================] - ETA: 0s - loss: 0.2003
# Epoch 00078: val_loss improved from 0.19580 to 0.19494, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.2003 - val_loss: 0.1949
# Epoch 79/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1995
# Epoch 00079: val_loss improved from 0.19494 to 0.19412, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.1995 - val_loss: 0.1941
# Epoch 80/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1987
# Epoch 00080: val_loss improved from 0.19412 to 0.19335, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 73ms/step - loss: 0.1987 - val_loss: 0.1934
# Epoch 81/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1979
# Epoch 00081: val_loss improved from 0.19335 to 0.19262, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 73ms/step - loss: 0.1979 - val_loss: 0.1926
# Epoch 82/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1972
# Epoch 00082: val_loss improved from 0.19262 to 0.19193, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.1972 - val_loss: 0.1919
# Epoch 83/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1966
# Epoch 00083: val_loss improved from 0.19193 to 0.19128, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.1966 - val_loss: 0.1913
# Epoch 84/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1959
# Epoch 00084: val_loss improved from 0.19128 to 0.19066, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 73ms/step - loss: 0.1959 - val_loss: 0.1907
# Epoch 85/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1953
# Epoch 00085: val_loss improved from 0.19066 to 0.19007, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 46s 73ms/step - loss: 0.1953 - val_loss: 0.1901
# Epoch 86/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1947
# Epoch 00086: val_loss improved from 0.19007 to 0.18951, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.1947 - val_loss: 0.1895
# Epoch 87/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1942
# Epoch 00087: val_loss improved from 0.18951 to 0.18898, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.1942 - val_loss: 0.1890
# Epoch 88/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1937
# Epoch 00088: val_loss improved from 0.18898 to 0.18847, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 46s 73ms/step - loss: 0.1937 - val_loss: 0.1885
# Epoch 89/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1932
# Epoch 00089: val_loss improved from 0.18847 to 0.18799, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.1932 - val_loss: 0.1880
# Epoch 90/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1927
# Epoch 00090: val_loss improved from 0.18799 to 0.18753, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.1927 - val_loss: 0.1875
# Epoch 91/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1922
# Epoch 00091: val_loss improved from 0.18753 to 0.18708, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 73ms/step - loss: 0.1922 - val_loss: 0.1871
# Epoch 92/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1918
# Epoch 00092: val_loss improved from 0.18708 to 0.18666, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 46s 73ms/step - loss: 0.1918 - val_loss: 0.1867
# Epoch 93/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1914
# Epoch 00093: val_loss improved from 0.18666 to 0.18626, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 73ms/step - loss: 0.1914 - val_loss: 0.1863
# Epoch 94/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1910
# Epoch 00094: val_loss improved from 0.18626 to 0.18587, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 73ms/step - loss: 0.1910 - val_loss: 0.1859
# Epoch 95/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1906
# Epoch 00095: val_loss improved from 0.18587 to 0.18550, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 73ms/step - loss: 0.1906 - val_loss: 0.1855
# Epoch 96/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1902
# Epoch 00096: val_loss improved from 0.18550 to 0.18514, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 46s 73ms/step - loss: 0.1902 - val_loss: 0.1851
# Epoch 97/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1899
# Epoch 00097: val_loss improved from 0.18514 to 0.18480, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 72ms/step - loss: 0.1899 - val_loss: 0.1848
# Epoch 98/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1896
# Epoch 00098: val_loss improved from 0.18480 to 0.18447, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 46s 73ms/step - loss: 0.1896 - val_loss: 0.1845
# Epoch 99/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1892
# Epoch 00099: val_loss improved from 0.18447 to 0.18416, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 73ms/step - loss: 0.1892 - val_loss: 0.1842
# Epoch 100/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1889
# Epoch 00100: val_loss improved from 0.18416 to 0.18385, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 73ms/step - loss: 0.1889 - val_loss: 0.1839
# Epoch 101/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1886
# Epoch 00101: val_loss improved from 0.18385 to 0.18356, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.1886 - val_loss: 0.1836
# Epoch 102/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1883
# Epoch 00102: val_loss improved from 0.18356 to 0.18327, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.1883 - val_loss: 0.1833
# Epoch 103/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1880
# Epoch 00103: val_loss improved from 0.18327 to 0.18300, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 71ms/step - loss: 0.1880 - val_loss: 0.1830
# Epoch 104/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1878
# Epoch 00104: val_loss improved from 0.18300 to 0.18274, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.1878 - val_loss: 0.1827
# Epoch 105/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1875
# Epoch 00105: val_loss improved from 0.18274 to 0.18248, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.1875 - val_loss: 0.1825
# Epoch 106/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1872
# Epoch 00106: val_loss improved from 0.18248 to 0.18224, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.1872 - val_loss: 0.1822
# Epoch 107/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1870
# Epoch 00107: val_loss improved from 0.18224 to 0.18200, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.1870 - val_loss: 0.1820
# Epoch 108/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1868
# Epoch 00108: val_loss improved from 0.18200 to 0.18177, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.1868 - val_loss: 0.1818
# Epoch 109/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1865
# Epoch 00109: val_loss improved from 0.18177 to 0.18155, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.1865 - val_loss: 0.1815
# Epoch 110/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1863
# Epoch 00110: val_loss improved from 0.18155 to 0.18133, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.1863 - val_loss: 0.1813
# Epoch 111/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1861
# Epoch 00111: val_loss improved from 0.18133 to 0.18112, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 71ms/step - loss: 0.1861 - val_loss: 0.1811
# Epoch 112/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1859
# Epoch 00112: val_loss improved from 0.18112 to 0.18092, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.1859 - val_loss: 0.1809
# Epoch 113/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1857
# Epoch 00113: val_loss improved from 0.18092 to 0.18072, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.1857 - val_loss: 0.1807
# Epoch 114/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1855
# Epoch 00114: val_loss improved from 0.18072 to 0.18053, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.1855 - val_loss: 0.1805
# Epoch 115/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1853
# Epoch 00115: val_loss improved from 0.18053 to 0.18034, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.1853 - val_loss: 0.1803
# Epoch 116/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1851
# Epoch 00116: val_loss improved from 0.18034 to 0.18016, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.1851 - val_loss: 0.1802
# Epoch 117/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1849
# Epoch 00117: val_loss improved from 0.18016 to 0.17999, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.1849 - val_loss: 0.1800
# Epoch 118/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1847
# Epoch 00118: val_loss improved from 0.17999 to 0.17982, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.1847 - val_loss: 0.1798
# Epoch 119/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1845
# Epoch 00119: val_loss improved from 0.17982 to 0.17965, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.1845 - val_loss: 0.1797
# Epoch 120/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1844
# Epoch 00120: val_loss improved from 0.17965 to 0.17949, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.1844 - val_loss: 0.1795
# Epoch 121/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1842
# Epoch 00121: val_loss improved from 0.17949 to 0.17933, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 45s 71ms/step - loss: 0.1842 - val_loss: 0.1793
# Epoch 122/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1840
# Epoch 00122: val_loss improved from 0.17933 to 0.17918, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.1840 - val_loss: 0.1792
# Epoch 123/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1839
# Epoch 00123: val_loss improved from 0.17918 to 0.17903, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.1839 - val_loss: 0.1790
# Epoch 124/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1837
# Epoch 00124: val_loss improved from 0.17903 to 0.17888, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.1837 - val_loss: 0.1789
# Epoch 125/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1836
# Epoch 00125: val_loss improved from 0.17888 to 0.17874, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.1836 - val_loss: 0.1787
# Epoch 126/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1834
# Epoch 00126: val_loss improved from 0.17874 to 0.17860, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.1834 - val_loss: 0.1786
# Epoch 127/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1833
# Epoch 00127: val_loss improved from 0.17860 to 0.17847, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.1833 - val_loss: 0.1785
# Epoch 128/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1832
# Epoch 00128: val_loss improved from 0.17847 to 0.17833, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.1832 - val_loss: 0.1783
# Epoch 129/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1830
# Epoch 00129: val_loss improved from 0.17833 to 0.17820, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.1830 - val_loss: 0.1782
# Epoch 130/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1829
# Epoch 00130: val_loss improved from 0.17820 to 0.17808, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.1829 - val_loss: 0.1781
# Epoch 131/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1828
# Epoch 00131: val_loss improved from 0.17808 to 0.17795, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.1828 - val_loss: 0.1780
# Epoch 132/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1826
# Epoch 00132: val_loss improved from 0.17795 to 0.17783, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.1826 - val_loss: 0.1778
# Epoch 133/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1825
# Epoch 00133: val_loss improved from 0.17783 to 0.17771, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.1825 - val_loss: 0.1777
# Epoch 134/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1824
# Epoch 00134: val_loss improved from 0.17771 to 0.17760, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.1824 - val_loss: 0.1776
# Epoch 135/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1823
# Epoch 00135: val_loss improved from 0.17760 to 0.17748, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.1823 - val_loss: 0.1775
# Epoch 136/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1822
# Epoch 00136: val_loss improved from 0.17748 to 0.17737, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.1822 - val_loss: 0.1774
# Epoch 137/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1820
# Epoch 00137: val_loss improved from 0.17737 to 0.17726, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.1820 - val_loss: 0.1773
# Epoch 138/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1819
# Epoch 00138: val_loss improved from 0.17726 to 0.17716, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.1819 - val_loss: 0.1772
# Epoch 139/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1818
# Epoch 00139: val_loss improved from 0.17716 to 0.17705, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.1818 - val_loss: 0.1771
# Epoch 140/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1817
# Epoch 00140: val_loss improved from 0.17705 to 0.17695, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.1817 - val_loss: 0.1769
# Epoch 141/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1816
# Epoch 00141: val_loss improved from 0.17695 to 0.17685, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.1816 - val_loss: 0.1768
# Epoch 142/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1815
# Epoch 00142: val_loss improved from 0.17685 to 0.17675, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1815 - val_loss: 0.1767
# Epoch 143/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1814
# Epoch 00143: val_loss improved from 0.17675 to 0.17665, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.1814 - val_loss: 0.1767
# Epoch 144/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1813
# Epoch 00144: val_loss improved from 0.17665 to 0.17656, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.1813 - val_loss: 0.1766
# Epoch 145/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1812
# Epoch 00145: val_loss improved from 0.17656 to 0.17646, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.1812 - val_loss: 0.1765
# Epoch 146/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1811
# Epoch 00146: val_loss improved from 0.17646 to 0.17637, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.1811 - val_loss: 0.1764
# Epoch 147/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1810
# Epoch 00147: val_loss improved from 0.17637 to 0.17628, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.1810 - val_loss: 0.1763
# Epoch 148/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1809
# Epoch 00148: val_loss improved from 0.17628 to 0.17619, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.1809 - val_loss: 0.1762
# Epoch 149/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1808
# Epoch 00149: val_loss improved from 0.17619 to 0.17610, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.1808 - val_loss: 0.1761
# Epoch 150/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1807
# Epoch 00150: val_loss improved from 0.17610 to 0.17601, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1807 - val_loss: 0.1760
# Epoch 151/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1806
# Epoch 00151: val_loss improved from 0.17601 to 0.17593, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1806 - val_loss: 0.1759
# Epoch 152/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1806
# Epoch 00152: val_loss improved from 0.17593 to 0.17585, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1806 - val_loss: 0.1758
# Epoch 153/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1805
# Epoch 00153: val_loss improved from 0.17585 to 0.17576, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1805 - val_loss: 0.1758
# Epoch 154/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1804
# Epoch 00154: val_loss improved from 0.17576 to 0.17568, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 71ms/step - loss: 0.1804 - val_loss: 0.1757
# Epoch 155/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1803
# ...
# Epoch 00449: val_loss improved from 0.16611 to 0.16610, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1702 - val_loss: 0.1661
# Epoch 450/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1701
# Epoch 00450: val_loss improved from 0.16610 to 0.16608, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1701 - val_loss: 0.1661
# Epoch 451/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1701
# Epoch 00451: val_loss improved from 0.16608 to 0.16606, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1701 - val_loss: 0.1661
# Epoch 452/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1701
# Epoch 00452: val_loss improved from 0.16606 to 0.16605, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1701 - val_loss: 0.1660
# Epoch 453/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1701
# Epoch 00453: val_loss improved from 0.16605 to 0.16603, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1701 - val_loss: 0.1660
# Epoch 454/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1701
# Epoch 00454: val_loss improved from 0.16603 to 0.16601, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1701 - val_loss: 0.1660
# Epoch 455/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1701
# Epoch 00455: val_loss improved from 0.16601 to 0.16600, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1701 - val_loss: 0.1660
# Epoch 456/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1700
# Epoch 00456: val_loss improved from 0.16600 to 0.16598, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1700 - val_loss: 0.1660
# Epoch 457/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1700
# Epoch 00457: val_loss improved from 0.16598 to 0.16597, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1700 - val_loss: 0.1660
# Epoch 458/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1700
# Epoch 00458: val_loss improved from 0.16597 to 0.16595, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1700 - val_loss: 0.1659
# Epoch 459/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1700
# Epoch 00459: val_loss improved from 0.16595 to 0.16593, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1700 - val_loss: 0.1659
# Epoch 460/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1700
# Epoch 00460: val_loss improved from 0.16593 to 0.16592, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1700 - val_loss: 0.1659
# Epoch 461/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1699
# Epoch 00461: val_loss improved from 0.16592 to 0.16590, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1699 - val_loss: 0.1659
# Epoch 462/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1699
# Epoch 00462: val_loss improved from 0.16590 to 0.16589, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1699 - val_loss: 0.1659
# Epoch 463/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1699
# Epoch 00463: val_loss improved from 0.16589 to 0.16587, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1699 - val_loss: 0.1659
# Epoch 464/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1699
# Epoch 00464: val_loss improved from 0.16587 to 0.16585, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1699 - val_loss: 0.1659
# Epoch 465/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1699
# Epoch 00465: val_loss improved from 0.16585 to 0.16584, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1699 - val_loss: 0.1658
# Epoch 466/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1699
# Epoch 00466: val_loss improved from 0.16584 to 0.16582, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1699 - val_loss: 0.1658
# Epoch 467/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1698
# Epoch 00467: val_loss improved from 0.16582 to 0.16581, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1698 - val_loss: 0.1658
# Epoch 468/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1698
# Epoch 00468: val_loss improved from 0.16581 to 0.16579, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1698 - val_loss: 0.1658
# Epoch 469/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1698
# Epoch 00469: val_loss improved from 0.16579 to 0.16578, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1698 - val_loss: 0.1658
# Epoch 470/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1698
# Epoch 00470: val_loss improved from 0.16578 to 0.16576, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1698 - val_loss: 0.1658
# Epoch 471/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1698
# Epoch 00471: val_loss improved from 0.16576 to 0.16574, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1698 - val_loss: 0.1657
# Epoch 472/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1698
# Epoch 00472: val_loss improved from 0.16574 to 0.16573, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1698 - val_loss: 0.1657
# Epoch 473/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1697
# Epoch 00473: val_loss improved from 0.16573 to 0.16571, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1697 - val_loss: 0.1657
# Epoch 474/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1697
# Epoch 00474: val_loss improved from 0.16571 to 0.16570, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1697 - val_loss: 0.1657
# Epoch 475/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1697
# Epoch 00475: val_loss improved from 0.16570 to 0.16568, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1697 - val_loss: 0.1657
# Epoch 476/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1697
# Epoch 00476: val_loss improved from 0.16568 to 0.16567, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1697 - val_loss: 0.1657
# Epoch 477/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1697
# Epoch 00477: val_loss improved from 0.16567 to 0.16565, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1697 - val_loss: 0.1657
# Epoch 478/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1697
# Epoch 00478: val_loss improved from 0.16565 to 0.16564, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1697 - val_loss: 0.1656
# Epoch 479/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1696
# Epoch 00479: val_loss improved from 0.16564 to 0.16562, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1696 - val_loss: 0.1656
# Epoch 480/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1696
# Epoch 00480: val_loss improved from 0.16562 to 0.16561, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1696 - val_loss: 0.1656
# Epoch 481/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1696
# Epoch 00481: val_loss improved from 0.16561 to 0.16559, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1696 - val_loss: 0.1656
# Epoch 482/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1696
# Epoch 00482: val_loss improved from 0.16559 to 0.16558, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1696 - val_loss: 0.1656
# Epoch 483/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1696
# Epoch 00483: val_loss improved from 0.16558 to 0.16556, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1696 - val_loss: 0.1656
# Epoch 484/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1696
# Epoch 00484: val_loss improved from 0.16556 to 0.16555, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1696 - val_loss: 0.1655
# Epoch 485/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1695
# Epoch 00485: val_loss improved from 0.16555 to 0.16553, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1695 - val_loss: 0.1655
# Epoch 486/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1695
# Epoch 00486: val_loss improved from 0.16553 to 0.16552, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1695 - val_loss: 0.1655
# Epoch 487/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1695
# Epoch 00487: val_loss improved from 0.16552 to 0.16550, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1695 - val_loss: 0.1655
# Epoch 488/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1695
# Epoch 00488: val_loss improved from 0.16550 to 0.16549, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1695 - val_loss: 0.1655
# Epoch 489/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1695
# Epoch 00489: val_loss improved from 0.16549 to 0.16547, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1695 - val_loss: 0.1655
# Epoch 490/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1695
# Epoch 00490: val_loss improved from 0.16547 to 0.16546, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1695 - val_loss: 0.1655
# Epoch 491/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1694
# Epoch 00491: val_loss improved from 0.16546 to 0.16544, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1694 - val_loss: 0.1654
# Epoch 492/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1694
# Epoch 00492: val_loss improved from 0.16544 to 0.16543, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1694 - val_loss: 0.1654
# Epoch 493/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1694
# Epoch 00493: val_loss improved from 0.16543 to 0.16541, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1694 - val_loss: 0.1654
# Epoch 494/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1694
# Epoch 00494: val_loss improved from 0.16541 to 0.16540, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1694 - val_loss: 0.1654
# Epoch 495/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1694
# Epoch 00495: val_loss improved from 0.16540 to 0.16538, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1694 - val_loss: 0.1654
# Epoch 496/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1694
# Epoch 00496: val_loss improved from 0.16538 to 0.16537, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1694 - val_loss: 0.1654
# Epoch 497/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1693
# Epoch 00497: val_loss improved from 0.16537 to 0.16535, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1693 - val_loss: 0.1654
# Epoch 498/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1693
# Epoch 00498: val_loss improved from 0.16535 to 0.16534, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1693 - val_loss: 0.1653
# Epoch 499/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1693
# Epoch 00499: val_loss improved from 0.16534 to 0.16532, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1693 - val_loss: 0.1653
# Epoch 500/500
# 625/625 [==============================] - ETA: 0s - loss: 0.1693
# Epoch 00500: val_loss improved from 0.16532 to 0.16531, saving model to /content/gdrive/My Drive/VIP_Project/conv3d_checkpoint_generator
# 625/625 [==============================] - 44s 70ms/step - loss: 0.1693 - val_loss: 0.1653

# %%
seq.load_weights(checkpoint_filepath)

# %%
batch_size=1000
for sequence in range(1,7,1):
    track = x_te[sequence, :20, ::, ::, ::]
    y_prediction = seq.predict(track[np.newaxis])
    #print(y_prediction.shape)
    # ground truth
    plt.figure(figsize=(20,10))
    for i in range(20):
        plt.subplot(1, 20, i+1)
        plt.tick_params(
        axis='both',       # changes apply to the x-axis
        which='both',      # both major and minor ticks are affected
        bottom='off',      # ticks along the bottom edge are off
        top='off',         # ticks along the top edge are off
        labelbottom='off', # labels along the bottom edge are off
        labelleft='off')
        plt.imshow(te_set[sequence,i,:,:,:])

    # prediction
    plt.figure(figsize=(20,10))
    plt.subplot(1,20,1)
    plt.imshow(np.zeros((64,64,3)))
    for i in range(19):
        plt.subplot(1, 20, i+2) 
        plt.tick_params(
        axis='both',       # changes apply to the x-axis
        which='both',      # both major and minor ticks are affected
        bottom='off',      # ticks along the bottom edge are off
        top='off',         # ticks along the top edge are off
        labelbottom='off', # labels along the bottom edge are off
        labelleft='off')
        plt.imshow(y_prediction[0,i,:,:,:])

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from skimage.metrics import structural_similarity as ssim
from skimage import img_as_float32

te_set = img_as_float32(te_set)
y_prediction = seq.predict(x_te[:, :20, ::, ::, ::])

mse=0
mae=0
ssim_v=0

for i in range(batch_size):
  mse_i=0
  mae_i=0
  ssim_i=0
  for j in range(19):
    mse_total=0
    mae_total=0
    ssim_total=0
    for k in range(3):
      mse_total += mean_squared_error(te_set[i,j+1,:,:,k],y_prediction[i,j,:,:,k])
      mae_total += mean_absolute_error(te_set[i,j+1,:,:,k],y_prediction[i,j,:,:,k])
      ssim_total += ssim(te_set[i,j+1,:,:,k],y_prediction[i,j,:,:,k],data_range=y_prediction[i,j,:,:,k].max() - y_prediction[i,j,:,:,k].min())
    mse_i += mse_total/3
    mae_i += mae_total/3
    ssim_i += ssim_total/3

  mse += mse_i
  mae += mae_i
  ssim_v += ssim_i

mse = mse/(batch_size*19)
mae = mae/(batch_size*19)
ssim_v = ssim_v/(batch_size*19)

print('MSE: ',mse)
print('MAE: ',mae)
print('SSIM: ',ssim_v)
# Out:
# MSE:  0.2592062915806709
# MAE:  0.3106145399350084
# SSIM:  0.22877029318362196
